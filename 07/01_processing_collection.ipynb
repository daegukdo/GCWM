# %% [markdown]
# ### 중첩 컬렉션
#
#  - 컬렉션은 데이터를 담을 수 있으며 이를 순차적인 접근을 통해 다룰 수 있다
#
#  - 컬렉션은 컬렉션 자체도 포함할 수 있다
#
#  - 이러한 특성을 이용해서 조립하고 분해하는 등으로 다룰 수 있다

# %% [markdown]
# #### 리스트 중첩하기
#
#  - 가장 많이 사용되는 중첩 컬렉션은 리스트이다

# %%
# 중첩 리스트
nested_list = [[1, 2, 3, 4], ['a', 'b', 'c', 'd'], [], [100, 200]]

# 중첩 리스트의 요소 읽기
nested_list[1][3]  # 'd'
# Out:
# 'd'

# %%
# 좌표평면 위의 도형을 나타내는 꼭지점의 좌표들
coordinates = [[0, 0, 2], [0, 2, 0], [2, 0, 0], [0, 0, 0], [0, 2, 2], [2, 2, 0], [2, 0, 2], [2, 2, 2]]

# 체스판에 놓인 말들
pieces = [
    ['A', 8, 'black', '룩'],
    ['D', 7, 'black', '킹'],
    ['C', 4, 'white', '비숍'],
    ['E', 1, 'white', '킹'],
]

# 서가에 보관해 둔 도서 정보
books = [
    ['파이썬으로 시작하는 컴퓨터 과학 입문', ['존 M. 젤']],
    ['파이썬을 활용한 데이터 길들이기', ['J. 카질', 'K. 자멀']],
    ['HTTP 완벽 가이드', ['D. 고울리', 'B. 토티', 'M. 세이어', 'S. 레디']],
]

# %%
# %matplotlib notebook

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(len(coordinates)):
    xs = coordinates[i][0]
    ys = coordinates[i][1]
    zs = coordinates[i][2]
    ax.scatter(xs, ys, zs, c='blue', marker='o')
    
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
#  - 이처럼 리스트로 어떤 데이터들을 한번에 표현할 수 있다
#
#  - **이때 어떤 것을 위와 같은 리스트로 표현하기 위해서는 대상을 추상화하고 특성을 잘 요약, 추려야한다**
#
#  - 예를 들어 아래와 같이 **데이터를 설계**할 수 있다

# %%
# 체스판(그리고 그 위에 놓인 말들)
board = [
    [['black', '룩'], None, None, None, None, None, None, None],
    [None, None, None, ['black', '킹'], None, None, None, None],
    [None, None, None, None, None, None, None, None],
    [None, None, None, None, None, None, None, None],
    [None, None, ['white', '비숍'], None, None, None, None, None],
    [None, None, None, None, None, None, None, None],
    [None, None, None, None, None, None, None, None],
    [None, None, None, None, ['white', '킹'], None, None, None],
]

# %%
from IPython.display import Image
Image("img/01_img.png")

# %% [markdown]
#  - 다양한 방식으로 리스트를 만들 수 있음을 확인했다
#
#  - 그렇다면 다양한 구조의 리스트의 특정 값에 접근하는 방법은?

# %%
# 중첩된 리스트의 요소에 접근하기

nested_list = [[1, 2, 3], [4, [5, 6, [7, 8]]]]

print(nested_list[0])           # ❶

print(nested_list[0][1])        # ❷

print(nested_list[1])

print(nested_list[1][1])

print(nested_list[1][1][2])     # ❸

print(nested_list[1][1][2][0])  # ❹
# Out:
# [1, 2, 3]
# 2
# [4, [5, 6, [7, 8]]]
# [5, 6, [7, 8]]
# [7, 8]
# 7

# %% [markdown]
# ##### 연습문제 7-1 중첩 리스트로 데이터 나타내기
#
# 다음은 9월 1일의 지역별 날씨를 나타내는 정보다. 이 정보를 중첩 리스트를 사용해 나타내 보아라.

# %%
Image("img/02_img.png")

# %% [markdown]
# #### 사전과 리스트의 중첩
#
#  - 리스트로만 데이터를 구조화하여 나타낼 때 하나의 문제점은 각 요소가 어떤 정보인지 알 수 없다
#
#  > 위의 좌표 값 중에 x, y를 알고 싶다면 어떻게 해야할까?
#
#  - 이를 사전과 같이 중첩하여 표현하면 데이터를 각 요소에 대한 정보와 함께 구조화할 수 있다

# %%
# 좌표평면 위의 도형을 나타내는 꼭지점의 좌표들
coordinates = [
    {'x': 0, 'y': 0},
    {'x': 0, 'y': 9},
    {'x': 8, 'y': 9},
    {'x': 8, 'y': 0},
]

# 체스판에 놓인 말들
pieces = [
    {'x': 'A', 'y': '8', 'color': 'black', 'role': '룩'},
    {'x': 'D', 'y': '7', 'color': 'black', 'role': '킹'},
    {'x': 'C', 'y': '4', 'color': 'white', 'role': '비숍'},
    {'x': 'E', 'y': '1', 'color': 'white', 'role': '킹'},
]

# 서가에 보관해 둔 도서 정보
books = [
    {'title': '파이썬으로 시작하는 컴퓨터 과학 입문',
     'authors': ['존 M. 젤']},
    {'title': '파이썬을 활용한 데이터 길들이기',
     'authors': ['J. 카질', 'K. 자멀']},
    {'title': 'HTTP 완벽 가이드',
     'authors': ['D. 고울리', 'B. 토티', 'M. 세이어', 'S. 레디']},
]

# %% [markdown]
#  - 리스트만으로의 중첩과 사전과 리스트가 함께하는 중첩의 비교는 아래와 같다
#
#  > 리스트와 사전을 중첩해 복잡한 형태의 정보를 표현할 수 있다.
#  >
#  > 한 개체의 여러 가지 특성을 표현할 때는 사전이 유리하다.
#  >
#  > 여러 개의 개체를 하나로 묶을 때는 리스트가 유리하다.

# %% [markdown]
# ##### 연습문제 7-2 리스트와 사전을 이용해 데이터 나타내기
#
#  - 연습문제 7-1에서 정의한 날씨 정보를 리스트와 사전을 이용해 다시 정의해 보자.

# %% [markdown]
# #### 양이 많은 데이터를 쉽게 나타내고 읽는 방법
#
#  - 리스트와 사전을 이용하면 데이터를 원하는데로 구조화할 수 있지만 코드가 길어진다
#
#  - 즉, 변수가 길어진다
#
#  - 이렇게 길어진 구조를 가지는 변수를 쉽고 깔끔하게 표현하는 방법이 없을까?

# %%
# 한 행에 걸쳐 모두 표기한 스타일 ... 1)
books1 = [{'title': '파이썬으로 시작하는 컴퓨터 과학 입문', 'authors': ['존 M. 젤']}, {'title': '파이썬을 활용한 데이터 길들이기', 'authors': ['J. 카질', 'K. 자멀']}, {'title': 'HTTP 완벽 가이드', 'authors': ['D. 고울리', 'B. 토티', 'M. 세이어', 'S. 레디']}]

# 리스트를 여러 행에 걸쳐 작성하기 ... 2)
books2 = [
    {'title': '파이썬으로 시작하는 컴퓨터 과학 입문', 'authors': ['존 M. 젤']},
    {'title': '파이썬을 활용한 데이터 길들이기', 'authors': ['J. 카질', 'K. 자멀']},
    {'title': 'HTTP 완벽 가이드', 'authors': ['D. 고울리', 'B. 토티', 'M. 세이어', 'S. 레디']},
]

# 리스트와 리스트에 포함된 사전을 여러 행으로 나누어 작성하기 ... 3)
books3 = [
    {
        'title': '파이썬으로 시작하는 컴퓨터 과학 입문',
        'authors': ['존 M. 젤']
    },
    {
        'title': '파이썬을 활용한 데이터 길들이기',
        'authors': ['J. 카질', 'K. 자멀']
    },
    {
        'title': 'HTTP 완벽 가이드',
        'authors': ['D. 고울리', 'B. 토티', 'M. 세이어', 'S. 레디']
    },
]

# %% [markdown]
#  - 각 방법에 대한 설명은 아래와 같다.
#
#  > 1) books1은 한 행에 모든 내용을 넣는 방식이다. 이런 방식은 눈으로 봤을 때는 데이터의 내용을 파악하기가 힘들다.
#  >
#  > 2) books2는 리스트를 여러 행에 걸쳐 작성했다. 리스트의 각각의 요소는 한 행에 하나씩, 한 단계씩 들여쓰기되어 작성되었다. 다만 요소(사전)의 크기가 크다보니 한 행에 표시되는 코드의 양을 줄이기 위해 한 번씩 개행을 했다.
#  >
#  > 3) books3은 리스트와 사전을 모두 여러 행에 걸쳐 작성한 것이다. 리스트의 요소를 한 단계씩 개행했고, 사전의 키-값 쌍도 한 단계씩 더 개행하여 나타냈다.
#
#  - books2와 books3의 스타일처럼 컬렉션의 중첩 구조를 드러내는 스타일을 추천

# %% [markdown]
#  - 이렇게 구조화 작업을 진행하는 경우에 데이터가 어떻게 생겨먹었는지 확인인하는게 매우 중요
#
#  - 보통 출력(ex - print 함수)으로 확인을 진행하는데 한눈에 잘들어오지 않음
#
#  - 이를 위한 함수가 있으니 ...  pprint() 함수(pretty print를 의미)를 사용!

# %%
# 컬렉션을 출력했을 때
print(books3)
# Out:
# [{'title': '파이썬으로 시작하는 컴퓨터 과학 입문', 'authors': ['존 M. 젤']}, {'title': '파이썬을 활용한 데이터 길들이기', 'authors': ['J. 카질', 'K. 자멀']}, {'title': 'HTTP 완벽 가이드', 'authors': ['D. 고울리', 'B. 토티', 'M. 세이어', 'S. 레디']}]

# %%
import pprint  # pprint() 함수가 들어있는 모듈을 임포트
pprint.pprint(books3)
# Out:
# [{'authors': ['존 M. 젤'], 'title': '파이썬으로 시작하는 컴퓨터 과학 입문'},
#  {'authors': ['J. 카질', 'K. 자멀'], 'title': '파이썬을 활용한 데이터 길들이기'},
#  {'authors': ['D. 고울리', 'B. 토티', 'M. 세이어', 'S. 레디'], 'title': 'HTTP 완벽 가이드'}]
