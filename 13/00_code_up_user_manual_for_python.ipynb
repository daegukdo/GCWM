# %% [markdown]
# ### code up 이란?
#
#  - 정보과학의 기초, 심화 및 한국정보올림피아드 대비 등의 정보과학 예제를 풀어볼 수 있는 알고리즘 트레이닝 사이트
#
#  - 원래는 경남정보고등학교 학생들을 위한 사이트였으나, 점점 외부인 유입이 늘어나더니 사이트가 커지면서 학교나 신분에 상관 없이 정보과학 알고리즘 트레이닝을 할 수 있는 곳으로 성장했다.
#
#  - CodeUp은 한국정보올림피아드 대비 외에도 프로그래밍 초보자가 프로그래밍 입문을 쉽게 할 수 있도록 도와준다.
#
#  - 사이트에 수행평가 기능이 있다 보니, 정보 과목이 있는 다른 학교에서 CodeUp을 이용해서 수행평가를 보거나 수업을 하는 경우가 많다.

# %% [markdown]
# ### 사용법
#
#  - code up을 검색하여 페이지에 진입한다
#
#  - 그리고 오른쪽 상단에 있는 가입하기 버튼을 눌러 회원가입을 진행한다
#
#  - 회원가입 후 로그인을 수행한다

# %%
from IPython.display import Image
Image("img/01_img.png")

# %%
Image("img/02_img.png")

# %%
Image("img/03_img.png")

# %% [markdown]
#  - 로그인 이후 왼쪽 상단에 문제 탭에서 문제집을 선택한다

# %%
Image("img/04_img.png")

# %% [markdown]
#  - 문제집에서 기초1. 출력문부터 연습으로 풀어본다
#
#  - 완료한 문제는 오른쪽 문제들 준 번호 옆에 'Y'라는 표기가 붙는다
#
#  - 연습으로 1002 문제를 풀어보자

# %%
Image("img/05_img.png")

# %% [markdown]
#  - 연습으로 1002 문제를 풀기 위해 그 해당 문제를 클릭한다
#
#  - 위에서 문제를 선택하면 아래와 같은 페이지로 진입한다
#
#  - 문제 설명으로부터 어떤 문제를 해결해야하는지 확인할 수 있다
#
#  - 그리고 소스 제출 버튼을 눌러 문제를 풀어볼 수 있다

# %%
Image("img/06_img.png")

# %% [markdown]
#  - 소스 제출을 선택하면 문제를 풀 수 있는 웹 환경이 제시된다
#
#  - 하단의 공백 라인에 문제에 대한 코드 답안을 기입한다
#
#  - 이때 python으로 문제를 풀 것이므로 아래에 노란색 형광으로 칠해진 바와 같이 python으로 선택한다
#
#  - 문제에 대한 코드 답안을 모두 작성하면 하단에 제출 버튼을 눌러 답이 맞는지 채점을 진행한다

# %%
Image("img/07_img.png")

# %% [markdown]
#  - 답안 제출 후 결과 탭에서 채점 중이라는 것을 확인할 수 있다
#
#  - 문제를 맞추면 정확한 풀이라는 것을 결과 탭에서 확인할 수 있다
#
#  - 결과가 나오면 이 코드에 사용된 메모리 시간 언어 코드 길이 등등이 같이 제시된다

# %%
Image("img/08_img.png")

# %% [markdown]
#  - 답안이 필리면 잘못된 풀이라는 결과를 확인할 수 있다
#
#  - 클릭 버튼을 통해 내 결과와 예상 결과를 비교할 수 있다

# %%
Image("img/09_img.png")

# %% [markdown]
#  - 아래는 다시 문제를 잘 풀어낸 결과를 보여준다

# %%
Image("img/10_img.png")

# %% [markdown]
#  - 다시 문제집으로 돌아가면 기초 출력 / 출력 하기 2를 해결하였으므로 번호 옆에 'Y'라는 태그가 붙은 것을 확인할 수 있다

# %%
Image("img/11_img.png")
