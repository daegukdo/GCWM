# %% [markdown]
# ### 장고 관리자
#
#  - 관리자 화면을 한국어로 변경하길 원할 경우 `settings.py`중 `LANGUAGE_CODE = 'en-us'`를 `LANGUAGE_CODE = 'ko'`로 바꾸어 변경할 수 있다
#
#  - 방금 막 모델링 한 글들을 장고 관리자에서 추가하거나 수정, 삭제할 수 있다
#
#  - 이제 blog/admin.py 파일을 열어서 내용을 다음과 같이 바꾸자

# %%
from django.contrib import admin
from .models import Post

admin.site.register(Post)

# %% [markdown]
#  - 코드에서 알 수 있듯이 앞 장에서 정의했던 Post모델을 가져오고(import) 있다
#
#  - 관리자 페이지에서 만든 모델을 보려면 `admin.site.register(Post)`로 모델을 등록해야 해야한다
#
#  - 자, 이제 Post모델을 보자
#
#  - 웹 서버를 실행하려면 console에서 `python manage.py runserver`를 실행해야 한다
#
#  - 브라우저를 열고 주소창에 http://127.0.0.1:8000/admin/ 을 입력하면 아래와 같은 로그인 페이지를 볼 수 있다

# %%
from IPython.display import Image

# %%
Image("img/14_img.png")

# %%
Image("img/15_img.png")

# %% [markdown]
#  - 로그인하기 위해서는, 모든 권한을 가지는 슈퍼 사용자(superuser)를 생성해야 한다
#
#  - comand console로 돌아가서 `python manage.py createsuperuser`을 입력하자
#
#  > **NOTE** 새 터미널 창을 열고 virtualenv를 활성화 시켜 웹 서버를 실행시키고 난 후 명령어를 입력해야한다. 01 첫 번째 Django 프로젝트 장의 웹 서버 시작하기 섹션에서 명령어를 입력하는 방법을 배웠다
#
#  - 메시지가 나타나면 사용자 이름 (소문자, 공백 없이), 이메일 주소 및 암호를 입력한다
#
#  - password를 입력할 때 화면에 글자가 보이지 않는다는 점을 참고하자
#
#  -  보이지 않습니다. 작성한 후에 enter를 누르면 아래와 같은 실행 화면을 볼 수 있다
#
#  - 슈퍼 사용자로 사용할 username 과 email 주소를 잘 기억해야 한다
#
#  > ID: eornr@eornr.com
#  PW: asdf1234

# %%
Image("img/16_img.png")

# %% [markdown]
#  - 브라우저로 돌아와서 장고 관리자 페이지에서 슈퍼 사용자로 로그인한 후 대시보드를 확인하자
#
#  - 게시글로 가서 이것저것 시도해보자
#
#  - 여러 포스트들을 작성해보자

# %%
Image("img/17_img.png")
