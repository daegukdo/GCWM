# %% [markdown]
# ### 고등학교 확률과 통계를 응용
#
#  - 참고자료
#  > http://www.douclass.com/data/dbook/140205201233/data/unit/support/0/13%EA%B3%A0%EB%93%B1%ED%99%95%EB%A5%A0%EA%B3%BC%ED%86%B5%EA%B3%84%EA%B5%90%EA%B3%BC%EC%84%9C.pdf

# %%
from IPython.display import Image

# %%
Image("img/03_img.png")

# %% [markdown]
# ###### 이산확률변수 응용 1
#
#  - 위의 데이터 셋을 확진자의 모집단이라고 가정하자
#  - 여기서 확진자 3명을 뽑을 때 여자가 나오는 횟수를 X라고하면 X는 0, 1, 2이므로 이산 확률 변수
#  - 이러한 가정에서 임의의 확진자 3명을 뽑았을 때, 확진자의 성별이 여자일 확률
#  > 성별에 따른 확진자 수 ... 참조

# %% [markdown]
# ###### 이산확률변수 응용 2
#
#  - 위의 데이터 셋을 확진자의 모집단이라고 가정하자
#  - 여기서 확진자 3명을 뽑을 때 나이가 10대인 경우의 횟수를 X라고하면 X는 0, 1, 2이므로 이산 확률 변수
#  - 이러한 가정에서 임의의 확진자 3명을 뽑았을 때, 확진자의 나이가 10대일 확률
#  > 나이대별 확진자의 수 ... 참조

# %%
Image("img/00_img.png")

# %% [markdown]
# ###### 평균과 표준편차 응용
#
#  - 위의 데이터 셋을 확진자의 모집단이라고 가정하자
#  - 이러한 가정에서 확진자의 나이의 평균과 표준편차를 구해보자
#  - 이러한 데이터로부터 우리가 알 수 있는 것은?
#  > 나이대별 확진자의 수 ... 참조

# %% [markdown]
#  - 확진자가 10대일 확률을 이항분포로 둘 수 있음
#  - X = 확진자가 10대인가 ... X는 0 또는 1일 것임
#  - 평균(기대값)과 분산, 표준편차 등을 구할 수 있음

# %%
Image("img/01_img.png")

# %%
Image("img/02_img.png")

# %% [markdown]
#  - 확진자는 정규분포를 따른다?

# %%
Image("img/04_img.png")
